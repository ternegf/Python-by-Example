# %%
# *********************************************************************
#                                                                     *
# Program      : Challenge_010_v1_01.py                               *
# Written by   : George Ternent                                       *
# Date.        : 18-Nov-2023.                                         *
#                                                                     *
# Description : There are 2.204 pounds in a kilogram, ask the user to *
#               enter a weight in kilograms and convert it to pounds. *
#                                                                     *
# *********************************************************************
#                                                                     *
# Note: This  solution could easily be made generic & used to convert *
#       other things, such as meters to feet and inches.              *
#                                                                     *
# *********************************************************************
# Function(s)                                                         *
# *********************************************************************
#                                                                     *
# Name      Description                                               *
# ****      ***********                                               *
# alpha     Returns just the alpha characters in  the string that was *
#           passed (i.e. a-Z and A-Z).                                *
#                                                                     *
# *********************************************************************
# History                                                             *
# *********************************************************************
#                                                                     *
# Ref   Changed by        Date          Change(s)                     *
# ****  ***********       ****         **********                     *
# 0.01  George Ternent.   18-Nov-2023. Initial Version.               *
#                                                                     *
# *********************************************************************

# *********************************************************************
# F U N C T I O N S
# *********************************************************************

# –—------------------------------------------------------------------
# alpha
# –—------------------------------------------------------------------

    # -----------------
    return alpha_string
    # -----------------

# *********************************************************************
# M A I N  P R O G R A M
# *********************************************************************
# Out:
# Enter your name : Frank
# Your name is Frank.
