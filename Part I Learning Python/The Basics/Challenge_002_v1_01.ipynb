# %%
# *********************************************************************
#                                                                     *
# Program      : Challenge_002_v1_01.py                               *
# Written by   : George Ternent                                       *
# Date.        : 10-Nov-2023.                                         *
#                                                                     *
# Description : Ask  for the user’s first name and then ask for their *
#               surname and display the output message:               *
#                                                                     *
#               Hello [First Name] [Surname]                          *               
#                                                                     *
# *********************************************************************
# Function(s)                                                         *
# *********************************************************************
#                                                                     *
# Name          Description                                           *
# ****          ***********                                           *
# process_name  Returns just the alpha characters in  the string that *
#               was passed (i.e. a-Z and A-Z).                        *
#                                                                     *
# *********************************************************************
# History                                                             *
# *********************************************************************
#                                                                     *
# Ref   Changed by        Date          Change(s)                     *
# ****  ***********       ****         **********                     *
# 0.01  George Ternent.   10-Nov-2023. Initial Version.               *
#                                                                     *
# *********************************************************************

# *********************************************************************
# F U N C T I O N S
# *********************************************************************

# –—------------------------------------------------------------------
# process_name
# –—------------------------------------------------------------------
def process_name(name):
    """
    Processes a name string, using the alpha function defined
    in challenge #1 to remove any non-alpha characters.
    
    Arg(s):
        String to be proccessed.
        
    Returns:
        Processed string. 
    """
    name = alpha(name)
    name = name.title()
    
    # ---------
    return name
    # ---------

# *********************************************************************
# M A I N  P R O G R A M
# *********************************************************************
# Out:
# Enter your name : Frank
# Your name is Frank.
