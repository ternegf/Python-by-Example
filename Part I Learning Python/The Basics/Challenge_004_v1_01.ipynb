# %%
# *********************************************************************
#                                                                     *
# Program      : Challenge_004_v1_01.py                               *
# Written by   : George Ternent                                       *
# Date.        : 12-Nov-2023.                                         *
#                                                                     *
# Description : Ask  the user to enter two numbers, add them together *
#               and display the answer as:                            *
#                                                                     *
#               The total is [answer]                                 *
#                                                                     *
# *********************************************************************
# Function(s)                                                         *
# *********************************************************************
#                                                                     *
# Name              Description                                       *
# ****              ***********                                       *
# get_valid_number  Prompt  for  and  return  a  valid floating point *
#                   number.                                           *
#                                                                     *
# *********************************************************************
# History                                                             *
# *********************************************************************
#                                                                     *
# Ref   Changed by        Date          Change(s)                     *
# ****  ***********       ****         **********                     *
# 0.01  George Ternent.   12-Nov-2023. Initial Version.               *
#                                                                     *
# *********************************************************************

# *********************************************************************
# F U N C T I O N S
# *********************************************************************

# –—------------------------------------------------------------------
# get_valid_number
# –—------------------------------------------------------------------
def get_valid_number(prompt):
    """
    Input a number, validate it, prompting again if invalid, and
    return the validated number.
    
    Arg(s):
        Prompt.
        
    Returns:
        Validated Floating Point Number
    """
    valid_number = False
    while not valid_number:
        try:
            number_string = input(prompt)
            number_float  = float(number_string)
            valid_number = True
        except ValueError:
            valid_number = False

    # -----------------
    return number_float
    # -----------------

# *********************************************************************
# M A I N  P R O G R A M
# *********************************************************************
# Out:
# Enter your name : Frank
# Your name is Frank.
