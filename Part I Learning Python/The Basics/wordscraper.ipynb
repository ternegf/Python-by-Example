# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
chichi = pd.Series([1, 2, 3])
print(chichi.index)
type(chichi)
for num in chichi:
    print (num)
# Out:
# RangeIndex(start=0, stop=3, step=1)
# 1
# 2
# 3

# %%
chingching = pd.Series([4, 5, 6], index=["a","b","c"])
print(chingching)
print(chingching["b"])
print(chingching[0])
print(chingching.index)
print(chingching[["c","a","b"]])

chingching=chingching*3
print(chingching)

"b" in chingching
if "z" in chingching:
    print ("Z")
else:
    print("No Z")
# Out:
# a    4
# b    5
# c    6
# dtype: int64
# 5
# 4
# Index(['a', 'b', 'c'], dtype='object')
# c    6
# a    4
# b    5
# dtype: int64
# a    12
# b    15
# c    18
# dtype: int64
# No Z

# %%
turpin = {"ID1":"TERNEGF","ID2":"TERNEDL","ID3":"TERNEAS"}
yangguang = pd.Series(turpin)
print(yangguang)
dick = yangguang.to_dict()
print (dick)
my_index = ["ID2","ID1","ID3","ID4"]
tiantian = pd.Series(turpin, index=my_index)
print(tiantian)

#tiantian["ID4"] = "BUFFY"
#print(tiantian)
# Out:
# ID1    TERNEGF
# ID2    TERNEDL
# ID3    TERNEAS
# dtype: object
# {'ID1': 'TERNEGF', 'ID2': 'TERNEDL', 'ID3': 'TERNEAS'}
# ID2    TERNEDL
# ID1    TERNEGF
# ID3    TERNEAS
# ID4        NaN
# dtype: object

# %%
# Tai Shan and Mei Xiang, Bei Bei 
taishan = pd.Series([4, 5, 6], index=["a","b","c"])
meixian = pd.Series([7, 8, 9], index=["a","b","c"])

beibei = taishan ** meixian
beibei.name = "value"
beibei.index.name = "letter"
print(beibei)

beibei.index = ["LARRY","CURLY","MO"]
print(beibei)

# %%
#pd.isna(yangguang)
yangguang.isna()
# Out:
# ID1    False
# ID2    False
# ID3    False
# dtype: bool

# %%
#pd.notna(yangguang)
yangguang.notna()
# Out:
# ID1    True
# ID2    True
# ID3    True
# dtype: bool

# %%
 data = {"YEAR":[ 2008,  2011, 2016, 2024], "TITLE":["Kung Fu Panda", "Kung Fu Panda 2", "Kung Fu Panda 3", "Kung Fu Panda 4"], "DIRECTOR":["Mark Osborne", "Jennifer Yu Nelson", "Alessandro Carloni","Mike Mitchell"],"RATING":[7.6, 7.2, 7.1, None],"METASCORE":[74, 67, 66, None]}
    
frame = pd.DataFrame(data)
frame2 = pd.DataFrame(frame,columns=["YEAR", "TITLE","DIRECTOR","RATING","METASCORE","WRITTEN_BY"]) 

film_series = pd.Series((frame["TITLE"]))
# Out:
# 0      Kung Fu Panda
# 1    Kung Fu Panda 2
# 2    Kung Fu Panda 3
# 3    Kung Fu Panda 4
# Name: TITLE, dtype: object

# %%
print(f'\n')
#print(film_series)

#print(frame.loc[2])

for i in range(0,len(frame)):
    print(f'\n{frame.loc[i]}')
# Out:
# YEAR                  2008
# TITLE        Kung Fu Panda
# DIRECTOR      Mark Osborne
# RATING                 7.6
# METASCORE             74.0
# Name: 0, dtype: object
#
# YEAR                       2011
# TITLE           Kung Fu Panda 2
# DIRECTOR     Jennifer Yu Nelson
# RATING                      7.2
# METASCORE                  67.0
# Name: 1, dtype: object
#
# YEAR                       2016
# TITLE           Kung Fu Panda 3
# DIRECTOR     Alessandro Carloni
# RATING                      7.1
# METASCORE                  66.0
# Name: 2, dtype: object
#
# YEAR                    2024
# TITLE        Kung Fu Panda 4
# DIRECTOR       Mike Mitchell
# RATING                   NaN
# METASCORE                NaN
# Name: 3, dtype: object

# %%
frame.index = ["KFP1","KFP2","KFP3","KFP4"]
print (frame)
print (f'\n')
print(frame.loc[["KFP1","KFP3"],["DIRECTOR","YEAR"]])
print (f'\n')
print(frame.iloc[[2,0],[2,1]])
# Out:
#       YEAR            TITLE            DIRECTOR  RATING  METASCORE
# KFP1  2008    Kung Fu Panda        Mark Osborne     7.6       74.0
# KFP2  2011  Kung Fu Panda 2  Jennifer Yu Nelson     7.2       67.0
# KFP3  2016  Kung Fu Panda 3  Alessandro Carloni     7.1       66.0
# KFP4  2024  Kung Fu Panda 4       Mike Mitchell     NaN        NaN
#
#
#                 DIRECTOR  YEAR
# KFP1        Mark Osborne  2008
# KFP3  Alessandro Carloni  2016
#
#
#                 DIRECTOR            TITLE
# KFP3  Alessandro Carloni  Kung Fu Panda 3
# KFP1        Mark Osborne    Kung Fu Panda

# %%
x=[1,2,3]
y=x*3
y[0]=0
print(x)
print(y)

def arse(a,b,c=0):
    print(a+b+c)
    
values = [1, 2, 3]
arse(*values)

import pandas as pd

data = pd.Series([-1, 0, 3, 12, 0.6, -3])
list = [-1, 0, 3, 12, 0.6, -3]
print (data.min())
print (list.min())
# Out:
# [1, 2, 3]
# [0, 2, 3, 1, 2, 3, 1, 2, 3]
# 6
# -3.0
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-380f05a85c54> in <module>
#      16 list = [-1, 0, 3, 12, 0.6, -3]
#      17 print (data.min())
# ---> 18 print (list.min())
#
# AttributeError: 'list' object has no attribute 'min'
