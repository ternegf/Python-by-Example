# %%
# *********************************************************************
#                                                                     *
# Program      : Challenge_006_v1_01.py                               *
# Written by   : George Ternent                                       *
# Date.        : 14-Nov-2023.                                         *
#                                                                     *
# Description : Ask  how  many  slices of Pizza the user started with *
#               and  ask  how   many they have  eaten   Work  out how *
#               many  slices they have left and display the result in *
#               a user friendly format.                               *
#                                                                     *
# *********************************************************************
# Classes                                                             *
# *********************************************************************
#                                                                     *
# Name     Description                                                *
# ****     ***********                                                *
# Pizza    A  simple  model of a pizza that you create with anumbe of *
#          slices                                                     *
# *********************************************************************
# History                                                             *
# *********************************************************************
#                                                                     *
# Ref   Changed by        Date          Change(s)                     *
# ****  ***********       ****         **********                     *
# 0.01  George Ternent.   14-Nov-2023. Initial Version.               *
#                                                                     *
# *********************************************************************

from dataclasses import dataclass

# *********************************************************************
# C L A S S E S
# *********************************************************************

# –—------------------------------------------------------------------
# Pizza
# –—------------------------------------------------------------------
class Pizza():
    '''A simple model of a pizza that you create with anumbe of slices'''
        
    def __init__(self, slices):
        self.slices = slices
        
    def eat_slice(self):
        if self.slices > 0:
            self.slices = self.slices - 1
    # -----------------
    return alpha_string
    # -----------------

# *********************************************************************
# M A I N  P R O G R A M
# *********************************************************************
# Out:
# Enter your name : Frank
# Your name is Frank.
