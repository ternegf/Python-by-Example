# %%
# Zip two lists together
numbers = ["Bonjour!", "G’Day!", "Howdie!", "Strewth!"]
names = ["Pierre", "Bruce", "Clint", "Bruce"]
zipped_object = zip(numbers, names)

for number, name in zipped_object:
    print(f"{number}: {name}")
# Out:
# Bonjour!: Pierre
# G’Day!: Bruce
# Howdie!: Clint
# Strewth!: Bruce
